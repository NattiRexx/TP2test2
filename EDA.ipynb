# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

np.random.seed(0)
num_samples = 1000

STREETNAME = np.random.randint(18, 80, num_samples)
ALT_NAME = np.random.randint(100, 5000, num_samples)
OBJECT_ID = np.random.randint(1, 8, num_samples)

WATER_SUPP = np.random.randint(1, 10, num_samples)
SANITATION= np.random.randint(1, 10, num_samples)
lONGITUDE = np.random.randint(1, 10, num_samples)


LATITUDE = np.random.choice([0, 1], num_samples, p=[0.3, 0.7])
WARD_S = np.random.choice([0, 1], num_samples, p=[0.4, 0.6])
PLANNING_U = np.random.choice([0, 1], num_samples, p=[0.5, 0.5])

data = pd.DataFrame('C:\Users\GONGONET\Test-2\Informal_Settlement_Programme_-1898186875815614491.csv')


summary_stats = data.describe()
print(summary_stats)

# Basic infographic charts
plt.figure(figsize=(15, 5))

# Histogram 
plt.subplot(1, 3, 1)
sns.histplot(data['Age'], kde=True, bins=20, color='skyblue')
plt.title('Distribution of Age')

# Boxplot of Income vs. Electricity
plt.subplot(1, 3, 2)
sns.boxplot(x='Electricity', y='Income', data=data, palette='Set2')
plt.title('Income vs. Electricity Availability')

# Countplot of Sewerage
plt.subplot(1, 3, 3)
sns.countplot(x='Sewerage', data=data, palette='pastel')
plt.title('Sewerage Availability')

plt.tight_layout()
plt.show()

# Correlation Heatmap
plt.figure(figsize=(10, 6))
corr_matrix = data.corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# Pairplot
sns.pairplot(data, hue='Electricity', palette='coolwarm')
plt.title('Pairplot of Variables Colored by Electricity Availability')
plt.show()

# Highlighting patterns
plt.figure(figsize=(8, 6))
sns.histplot(data['Family Size'], kde=True, bins=10, color='salmon')
plt.title('Distribution of Family Size')
plt.axvline(data['Family Size'].mean(), color='blue', linestyle='--', label='Mean Family Size')
plt.legend()
plt.show()

plt.figure(figsize=(8, 6))
sns.countplot(x='Water', data=data, palette='coolwarm')
plt.title('Water Availability')
plt.show()

plt.figure
